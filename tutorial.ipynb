# %% [markdown]
# # Fraggler tutorial

# %% [markdown]
# Using data in the `demo` folder

# %% [markdown]
# # Imports

# %%
import fragment_analyzer
from pathlib import Path
import pandas as pd
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# # Fsa file

# %%
fsa = fragment_analyzer.FsaFile(
    file="demo/230515_Ny_mix_Dx/Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa", 
    ladder="LIZ",
)

# %% [markdown]
# ## Have a look a at the fsa object:

# %%
fsa
# Out:
#             FsaFile-object with following parameters:
#
#             File: demo/230515_Ny_mix_Dx/Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
#             Filename: Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
#             Size standard channel: DATA205
#             Ladder name: LIZ
#             Number of ladder steps: 35
#             Minimum interpeak distance: 30
#             Minimum height: 100
#             Minimum Ladder trace distance: 300
#             Maximum peak count: 38
#             Normalized data: False
#             Trace Channel: DATA1
#             Ladder Sizes: [ 20  40  60  80 100 114 120 140 160 180 200 214 220 240 260 280 300 314
#  320 340 360 380 400 414 420 440 460 480 500 514 520 540 560 580 600]

# %% [markdown]
# ## Ladder assigner and model

# %%
ladder_assigner = fragment_analyzer.PeakLadderAssigner(fsa)
model = fragment_analyzer.FitLadderModel(ladder_assigner)
# Out:
# Ladder fitting model: Pipeline(steps=[('splinetransformer',
#                  SplineTransformer(extrapolation='continue', n_knots=3)),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Look at the raw data

# %%
fragment_analyzer.PlotRawData(fsa).plot_raw_data

# %% [markdown]
# ## Plot the ladder and the fit of the model

# %%
fragment_analyzer.PlotLadder(model).plot_ladder_peaks

# %%
fragment_analyzer.PlotLadder(model).plot_model_fit

# %% [markdown]
# # Peak Areas
#
# ### Two different ways of finding peaks
# 1. Agnostic
# 2. Customized peak table

# %% [markdown]
# ## 1. Agnostic
#
#
# * Finds peaks without the user having to specify peaks and intervals (default option)

# %%
pam = fragment_analyzer.PeakAreaDeMultiplex(model)
# Out:
# 9 peaks found in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
# 4 assays in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa

# %% [markdown]
# ## Plot all peaks found in the fsa file

# %%
fragment_analyzer.PlotPeakArea(pam).plot_peaks()

# %% [markdown]
# ## 2. Custom Peak table
#
# The custom peak table must be a csv file and contain:
# - name: name of the assay
# - start: where the interval starts
# - stop: where the interval stops
# - amount: amount of peaks. A number of empty

# %%
# following peak table only specifies 1 peak in amount.
pam2 = fragment_analyzer.PeakAreaDeMultiplex(model, custom_peaks="tests/custom_peaks.csv")

# You can also pass the table as a pd.DataFrame:
peaks = pd.read_csv("tests/custom_peaks.csv")
pam3 = fragment_analyzer.PeakAreaDeMultiplex(model, custom_peaks=peaks)
display(peaks)
# Out:
# 1 peaks found in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
# 1 assays in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
#
# 1 peaks found in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
# 1 assays in Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa
#    name  start  stop  amount
# 0  prt1    210   240       1

# %% [markdown]
# ## Plot the peaks again (this time only one)

# %%
fragment_analyzer.PlotPeakArea(pam2).plot_peaks()

# %% [markdown]
# ## Plot the peak areas and the ratio of the peaks in all the assays
#
# Use different models:
# - "gauss"
# - "voigt"

# %%
for i in pam:
    plot = fragment_analyzer.PlotPeakArea(pam).plot_areas(assay_number=i, peak_finding_model="gauss")
    display(plot)

# %% [markdown]
# ## Look at the peak dataframe

# %%
pam.assays_dataframe()
# Out:
#    peak_height   basepairs  fitted_peak_height  model          area  r_value  \
# 0         1266  151.659667         1236.498852  gauss   5015.179740    0.994
# 1         1175  195.704319         1175.046092  gauss   5210.698689    0.985
# 2         1923  198.734241         1888.015410  gauss   8789.285475    0.984
# 3         1486  228.822437         1490.353434  gauss   5971.773851    0.995
# 4         1370  265.317577         1344.317063  gauss   6258.391405    0.991
# 5         1248  268.581174         1236.983617  gauss   5774.996527    0.983
# 6         1218  271.617223         1191.072195  gauss   5826.992560    0.984
# 7         1376  277.458470         1362.255852  gauss   6445.974849    0.985
# 8         2599  280.600919         2541.305382  gauss  12115.426734    0.988
#
#   peak_name                                file_name  quotient  peak_number  \
# 0    Peak 1  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  0.000000            1
# 1    Peak 1  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.686777            2
# 2    Peak 2  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.686777            2
# 3    Peak 1  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  0.000000            1
# 4    Peak 1  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.993787            5
# 5    Peak 2  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.993787            5
# 6    Peak 3  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.993787            5
# 7    Peak 4  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.993787            5
# 8    Peak 5  Multi 1ul_102__230515_Ny_mix_C06_Dx.fsa  1.993787            5
#
#    assay_number
# 0             1
# 1             2
# 2             2
# 3             3
# 4             4
# 5             4
# 6             4
# 7             4
# 8             4

# %% [markdown]
# ## Look at the fit reports of the model for each peak

# %%
for r in pam.fit_report:
    print(r)
    print("")
# Out:
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 18
#     # variables        = 3
#     chi-square         = 31737.4189
#     reduced chi-square = 2115.82793
#     Akaike info crit   = 140.547838
#     Bayesian info crit = 143.218954
#     R-squared          = 0.99117557
# [[Variables]]
#     amplitude:  6258.39141 +/- 142.947880 (2.28%) (init = 5985)
#     center:     3114.38370 +/- 0.04790311 (0.00%) (init = 3114.5)
#     sigma:      1.81626777 +/- 0.04790313 (2.64%) (init = 1.5)
#     fwhm:       4.27698368 +/- 0.11280324 (2.64%) == '2.3548200*sigma'
#     height:     1374.65251 +/- 31.3984106 (2.28%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) = 0.577
#
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 19
#     # variables        = 3
#     chi-square         = 47717.3435
#     reduced chi-square = 2982.33397
#     Akaike info crit   = 154.743613
#     Bayesian info crit = 157.576930
#     R-squared          = 0.98381776
# [[Variables]]
#     amplitude:  5774.99653 +/- 171.788927 (2.97%) (init = 5355)
#     center:     3143.07589 +/- 0.06392196 (0.00%) (init = 3143.5)
#     sigma:      1.86095879 +/- 0.06392195 (3.43%) (init = 1.5)
#     fwhm:       4.38222299 +/- 0.15052469 (3.43%) == '2.3548200*sigma'
#     height:     1238.01258 +/- 36.8272080 (2.97%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) = 0.577
#
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 18
#     # variables        = 3
#     chi-square         = 44125.3012
#     reduced chi-square = 2941.68675
#     Akaike info crit   = 146.479504
#     Bayesian info crit = 149.150619
#     R-squared          = 0.98434726
# [[Variables]]
#     amplitude:  5826.99256 +/- 172.307861 (2.96%) (init = 5224.5)
#     center:     3170.44797 +/- 0.06481110 (0.00%) (init = 3170.5)
#     sigma:      1.89810921 +/- 0.06481115 (3.41%) (init = 1.5)
#     fwhm:       4.46970554 +/- 0.15261858 (3.41%) == '2.3548200*sigma'
#     height:     1224.71025 +/- 36.2153751 (2.96%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) = 0.577
#
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 18
#     # variables        = 3
#     chi-square         = 51186.1225
#     reduced chi-square = 3412.40817
#     Akaike info crit   = 149.151335
#     Bayesian info crit = 151.822451
#     R-squared          = 0.98539422
# [[Variables]]
#     amplitude:  6445.97485 +/- 184.830506 (2.87%) (init = 5913)
#     center:     3221.86324 +/- 0.06233710 (0.00%) (init = 3221.5)
#     sigma:      1.88275706 +/- 0.06233716 (3.31%) (init = 1.5)
#     fwhm:       4.43355399 +/- 0.14679278 (3.31%) == '2.3548200*sigma'
#     height:     1365.85441 +/- 39.1641146 (2.87%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) = 0.577
#
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 153418.163
#     reduced chi-square = 9024.59781
#     Akaike info crit   = 184.903806
#     Bayesian info crit = 187.891003
#     R-squared          = 0.98853854
# [[Variables]]
#     amplitude:  12115.4267 +/- 300.142265 (2.48%) (init = 11313)
#     center:     3250.30309 +/- 0.05370180 (0.00%) (init = 3250.5)
#     sigma:      1.87729183 +/- 0.05370182 (2.86%) (init = 1.5)
#     fwhm:       4.42068434 +/- 0.12645811 (2.86%) == '2.3548200*sigma'
#     height:     2574.64297 +/- 63.7830154 (2.48%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amplitude, sigma) = 0.577

# %% [markdown]
# # Report generating
#
# Use inside python script or use the CLI tool (see below)

# %%
fragment_analyzer.peak_area_report?
# Out:
# Signature:
# fragment_analyzer.peak_area_report(
#     fsa_file: str,
#     ladder: str,
#     folder: str,
#     peak_model: str,
#     min_interpeak_distance: int = 30,
#     min_height: int = 100,
#     min_ratio: float = 0.1,
#     trace_channel: str = 'DATA9',
#     search_peaks_start: int = 100,
#     cutoff: float = None,
#     peak_height: int = 200,
#     custom_peaks: str = None,
# ) -> int
# Docstring:
# Generates an HTML report for the fragment analysis of an FSA file, including peak area data and plots.
#
# Parameters:
# -----------
# fsa_file : str
#     The path to the FSA file to be analyzed.
# ladder : str
#     The name of the ladder used in the FSA file.
# folder : str
#     The path to the output folder where the report will be saved.
# peak_model : str
#     The peak finding model used to identify peaks.
#
# Returns:
# --------
# int
#     An integer representing the status of the report generation:
#     - 0 if successful
#     - 1 if no peaks were found
#
# Raises:
# -------
# FileNotFoundError
#     If the specified FSA file cannot be found.
# IOError
#     If the report file cannot be saved.
# File:      ~/clinical_genomics/fragment-analysis/new/ladder_map/fragment_analyzer/reports/peak_area_report.py
# Type:      function

# %% [markdown]
# # Peak table generating
#
# Use inside python script or use the CLI tool (see below)

# %%
fragment_analyzer.generate_peak_table?
# Out:
# Signature:
# fragment_analyzer.generate_peak_table(
#     in_files: str | list,
#     ladder: str,
#     peak_model: str,
#     min_height: int = 100,
#     cutoff: int = 175,
#     min_ratio: float = 0.3,
#     trace_channel: str = 'DATA9',
#     custom_peaks: str = None,
# ) -> pandas.core.frame.DataFrame
# Docstring:
# Generate a combined dataframe of peaks for all input files.
#
# Args:
#     in_files (Union[str, List[str]]): Path(s) to the input .fsa files, or a directory containing them.
#     ladder (str): The ladder used for the fragment analysis.
#     peak_model (str): The peak model used for peak area calculations.
#     min_height (int, optional): The minimum peak height required for detection. Defaults to 100.
#     cutoff (int, optional): The cutoff value for peak area calculations. Defaults to 175.
#     min_ratio (float, optional): The minimum ratio required for peak detection. Defaults to 0.3.
#     trace_channel (str, optional): The channel used for trace data. Defaults to "DATA9".
#
# Returns:
#     pandas.DataFrame: A combined dataframe containing the peak positions and their corresponding areas.
#
# Reads all the input .fsa files and generates a combined dataframe of all the peaks detected in each file using the
# specified ladder and peak model. If a directory is provided instead of specific file paths, all .fsa files within
# the directory will be used. Peak detection is based on the specified peak model and other optional parameters,
# such as minimum peak height and cutoff value.
#
# Example:
# --------
# peak_df = generate_peak_table(
#     in_files="my_folder", ladder="LIZ", peak_model="gauss"
# )
# File:      ~/clinical_genomics/fragment-analysis/new/ladder_map/fragment_analyzer/functions/generate_peak_table.py
# Type:      function

# %% [markdown]
# # CLI Tool
#
# ### For use of the CLI tool, please see the documentation
