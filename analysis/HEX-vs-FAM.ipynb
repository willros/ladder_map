# %%
import pandas as pd
import numpy as np
import fragment_analyzer
from pathlib import Path
from natsort import natsorted
import altair as alt
import re
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
hex_color = "demo/230314_mutliplex_and_hex/PRT2_3_HEX_4091_C11_Dx.fsa"
hex_and_fam = "demo/230314_mutliplex_and_hex/PRT2_3_HEX_FAM_4091_C12_Dx.fsa"
fam = "demo/230316_triplets/PRT2_3b__442_C05.fsa"

# %%
fsa = fragment_analyzer.FsaFile(
    fam,
    "LIZ",
    trace_channel="DATA1",
)
pla = fragment_analyzer.PeakLadderAssigner(fsa)
model = fragment_analyzer.FitLadderModel(pla)
pam = fragment_analyzer.PeakAreaDeMultiplex(model, min_ratio=0.1)
# Out:
# 2 peaks found in PRT2_3b__442_C05.fsa
# 1 assays in PRT2_3b__442_C05.fsa

# %%
peak_plots = fragment_analyzer.PlotPeakArea(pam)
peak_plots.plot_peaks()

# %%
fragment_analyzer.peak_area_report(
    fam,
    "LIZ",
    "report_multiplex/",
    "gauss",
    #trace_channel="DATA10"
)
# Out:
# 2 peaks found in PRT2_3b__442_C05.fsa
# 1 assays in PRT2_3b__442_C05.fsa
# 0
